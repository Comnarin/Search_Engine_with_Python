# %%
import requests
from bs4 import BeautifulSoup 
import re
import unicodedata
import pythainlp.util
import spacy
from spacy.tokenizer import Tokenizer
from spacy.lang.en import English
#from pythainlp.summarize import extract_keywords
from pythainlp.summarize import summarize
import itertools
from urllib.parse import urljoin
import time
from pythainlp.tag import tag_provinces
from pythainlp.tokenize import word_tokenize as tokenizer
from datetime import datetime
import math

# %%
class spyder:
    def __init__( self ,links,base_url,depth ):
        self.base_url = base_url
        target_links={}
        for i in links:
            target_links[i]=0 
        self.target_links = target_links
        self.depth = depth
    
    def get_crawler(self):
        self.result_crawler = self.crawl(self.base_url,self.depth,0,set())
        return self.result_crawler
    
    def get_check_domain(self):
        self.check_domain_result = self.check_domain(self.base_url,self.get_crawler())
        return self.check_domain_result
    
    def get_check_not_domain(self):
        self.check_not_domain_result = self.check_not_domain(self.base_url,self.get_crawler())   
        return self.check_not_domain_result
    
    def get_check_ref(self):
        self.check_ref_result = self.check_ref(self.get_check_not_domain(),self.target_links)
        return self.check_ref_result
    
    def crawl(self,url,n, depth,visited):
        if depth < n :
            visited.add(url)
            headers = {'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.246"}
            time.sleep(0.3)
            response = requests.get(url,headers=headers)
            try:
                soup = BeautifulSoup(response.text, 'html.parser')
            except:
                soup = BeautifulSoup(response.text, 'lxml')
            links = soup.find_all('a')
            links = [link.get('href') for link in links if link.get('href') and not link.get('href').startswith('#')]
            links = [urljoin(url, link) for link in links if link]

            for link in links:
                if link not in visited:
                    link = link.replace(' ','')
                    visited.add(link)
                    if link.startswith(url):
                        self.crawl(link,n=n,depth=depth+1, visited=visited)
        return visited
    
    def check_domain(self,base_url,links):
        result= set()
        for link in links :
            if link.startswith(base_url):
                result.add(link)
        return result
    
    def check_not_domain(self,base_url,links):
        result= set()
        for link in links :
            if not link.startswith(base_url):
                result.add(link)
        return result
    
    def check_ref(self,links,target_links):
        for i in links:
            for j in target_links:
                if i.startswith(j):
                    target_links[j]+=1
        return target_links

# %%
import sqlite3
def create_db(self):
    conn = sqlite3.connect('inverted_index.db')

    # Create tables for words, documents, and word frequencies

    conn.execute('''
    CREATE TABLE words (
        ID INTEGER PRIMARY KEY,
        Word TEXT NOT NULL UNIQUE
    );
    ''')

    conn.execute('''
    CREATE TABLE documents (
        ID INTEGER PRIMARY KEY,
        Link TEXT NOT NULL UNIQUE ,
        Title TEXT,
        Body TEXT,
        Location TEXT,
        Ref INT,
        Time TEXT
    );
    ''')

    conn.execute('''
    CREATE TABLE word_frequencies (
        Word_ID INTEGER ,
        Doc_ID INTEGER ,
        Frequency INTEGER NOT NULL,
        TF_IDF REAL ,
        PRIMARY KEY (word_id, doc_id),
        FOREIGN KEY (word_id) REFERENCES words(id),
        FOREIGN KEY (doc_id) REFERENCES documents(id)
    );
    ''')
    conn.execute('''
    CREATE TABLE Temp_link(
        ID INTEGER PRIMARY KEY,
        Link TEXT NOT NULL UNIQUE
    );
    ''')

    conn.execute('''
    CREATE TABLE Domain_link(
        ID INTEGER PRIMARY KEY,
        Domain_Link TEXT NOT NULL UNIQUE
    );
    ''')
    conn.commit()

# %%
# def Crawl_to_temp(target_links,db):
#     conn = sqlite3.connect(db)
#     for i in target_links:
#         domain = conn.execute("SELECT id FROM domain_link  WHERE domain_link  = ?", (i,)).fetchone()
#         if not domain:
#             conn.execute("INSERT INTO domain_link (domain_link) VALUES (?)", (i,))
#             conn.commit()
#         web_spyder = spyder(target_links,i,2)
#         domainlinks  = web_spyder.get_check_domain()
#         for link in domainlinks:
#             conn.execute('''INSERT INTO Temp_link (Link) VALUES (?);''', (link,))
#             conn.commit()

# %%
def Crawl_to_temp(target_links,db):
    conn = sqlite3.connect(db)
    for j in target_links:
        domain = conn.execute("SELECT id FROM domain_link  WHERE domain_link  = ?", (j,)).fetchone()
        if not domain:
            conn.execute("INSERT INTO domain_link (domain_link) VALUES (?)", (j,))
            conn.commit()
    for i in target_links:
        web_spyder = spyder(target_links,i,2)
        domainlinks  = web_spyder.get_check_domain()
        for link in domainlinks:
            conn.execute('''INSERT INTO Temp_link (Link) VALUES (?);''', (link,))
            conn.commit()

# %%
target_links = ['http://www.bbc.com/news','http://www.thairath.co.th']
Crawl_to_temp(target_links,'inverted_index.db')

# %%
class Thai:
    def __init__(self,data:list):
        self.data_value = data
        self.sentence = self.get_sentence()
        self.summarize = self.get_summarize()
        self.word = self.get_word() 
    def make_sentence(self,list_word):
        list_word = [list_word]
        self.sentence_value = ''
        for i in list_word:
            for i in list_word:
                if pythainlp.util.countthai(i)<10:
                    list_word.remove(i)
        self.sentence_value = ' '.join(list_word)
        return self.sentence_value
    def get_sentence(self):
        self.sentence_result = self.make_sentence(self.data_value)
        return self.sentence_result
    def get_word(self):
        self.word_value = tokenizer(self.sentence, engine="newmm")
        return self.word_value
    def get_summarize(self):
        self.summarize_result =[]
        self.summarize_result = summarize(self.sentence,n=5)
        return self.summarize_result
    def location(self):
        self.data = self.get_tokenize()
        self.location_value = tag_provinces(self.data)
        self.Result_location = [entry for entry in self.location_value if entry[1] == 'B-LOCATION']
        return self.Result_location

# %%
def spacy_process(text):
    nlp = spacy.load('en_core_web_sm')
    doc = nlp(text)
    
#Tokenization and lemmatization 
    lemma_list = []
    for token in doc:
        lemma_list.append(token.lemma_)
    #print("Tokenize+Lemmatize:")
    #print(lemma_list)
    
    #Filter the stopword
    filtered_sentence =[] 
    for word in lemma_list:
        lexeme = nlp.vocab[word]
        if lexeme.is_stop == False:
            filtered_sentence.append(word) 
    
    #Remove punctuation
    punctuations="?:!.,;"
    for word in filtered_sentence:
        if word in punctuations:
            filtered_sentence.remove(word)
    #print(" ")
    #3print("Remove stopword & punctuation: ")
    #print(filtered_sentence)
    return filtered_sentence

# %%
def cleansing(body):
    for i in body:
        output = i.replace('\n', '  ').replace('\xa0', '  ').replace('®', ' ').replace(';', ' ').replace('â', ' ')
        output = " ".join(output.split())
    return output

# %%
def scrap_tags(url):
  response = requests.get(url)
  soup = BeautifulSoup(response.text, 'html.parser')
  try:
    title_tag = soup.find('title').text
  except:
    title_tag = soup.find('title')
  try:
    body_tag = soup.find('body')
    text_below_body = body_tag.get_text().lower()
  except:
    text_below_body = 'not found'
  body_list =[]
  body_list.append(text_below_body)
  return (body_list,title_tag)

# %%
def get_word(body):
    word_freq = {}
    for word in body:
        if word in word_freq:
            word_freq[word] += 1
        else:
            word_freq[word] = 1
    return word_freq

# %%
#เอาเพิ่ม
def get_ref():
    conn = sqlite3.connect('inverted_index.db')
    domain = conn.execute("SELECT domain_link FROM domain_link ;").fetchall()
    domain = [t[0] for t in domain]
    for i in domain :
        web = spyder(domain,i,1)
        ref = web.get_check_ref()
    return ref

# %%
#เอาเพิ่ม
def update_ref():
    conn = sqlite3.connect('../Week10/inverted_index2.db')
    domain = conn.execute("SELECT domain_link FROM domain_link ;").fetchall()
    domain = [t[0] for t in domain]
    for i in domain :
        web = spyder(domain,i,1)
        ref = web.get_check_ref()
    check_link = conn.execute("SELECT link FROM documents ;").fetchall()
    check_link = [t[0] for t in check_link]
    for j in check_link:
        for k in ref:
            if j.startswith(k):
                conn.execute('UPDATE documents SET REF = ? WHERE link = ? ', (ref[k], j,))
    conn.commit()

# %%
#เอาเพิ่ม
import locationtagger
def eng_location(data,title):
    entities = locationtagger.find_locations(text = data[0])
    location = entities.countries
    if location == []:
        entities = locationtagger.find_locations(text = title)
        location = entities.countries
        if location ==[]:
            location = ['None']
    return location

# %%
#เอาเพิ่ม
def check_lang(url:str):
    data_lang,title = scrap_tags(url)
    try:
        percent = pythainlp.util.countthai(data_lang[0][0])
        if percent >50:
            thai_nlp = Thai(data_lang[0]) 
            word = thai_nlp.word
            try:
                location = 'จ.'+max(thai_nlp.get_location().keys())
            except:
                location = 'Thailand'
            new_list = [s.strip().replace('"', '') for s in word if s.strip()]
            while '' in new_list:
                new_list.remove('')
            word = get_word(new_list)
            return data_lang,word,title,location
        else:
            clean_body=cleansing(data_lang)
            body = spacy_process(cleansing(data_lang))
            word = get_word(body)
            location = eng_location(data_lang,title)
            return clean_body,word,title,location
    except:
        clean_body=cleansing(data_lang)
        body = spacy_process(cleansing(data_lang))
        word = get_word(body)
        location = eng_location(data_lang,title)
        return clean_body,word,title,location

# %%
#เอาเพิ่ม
def make_doc(link,ref):
    link.replace(" ", "")
    d=dict()    
    body,word,title,location =check_lang(link)
    d['link']= link
    d['title'] = title
    d['body']=body
    d['location']=location
    d['word'] = word
    for i in ref:
        if link.startswith(i):
            d['ref'] = ref[i] 
    print(d)
    return d

# %%
def update_tf_idf():
    conn = sqlite3.connect('inverted_index.db',timeout=3)

    cursor = conn.execute('SELECT COUNT(*) FROM documents')
    N = cursor.fetchone()[0]
    
    cursor = conn.execute('SELECT ID, Word FROM words')
    words = cursor.fetchall()
    
    for word in words:
        word_id = word[0]
        word_str = word[1]

        cursor = conn.execute('SELECT Doc_ID, Frequency FROM word_frequencies WHERE Word_ID = ?', (word_id,))
        doc_freqs = cursor.fetchall()

        df = len(doc_freqs)
        idf = math.log(N / df)

        for doc_freq in doc_freqs:
            doc_id = doc_freq[0]
            tf = doc_freq[1]
            tf_idf = tf * idf
            conn.execute('UPDATE word_frequencies SET TF_IDF = ? WHERE Word_ID = ? AND Doc_ID = ?', (tf_idf, word_id, doc_id))

    conn.commit()

# %%
def insert_to_database(doc):
  conn = sqlite3.connect('inverted_index.db')
  for i in doc:
    conn.execute('''INSERT INTO documents (Link, Title, Body, Location, Ref, Time) VALUES (?, ?, ?, ?, ?, ?);''', (str(i['link']), str(i['title']), str(i['body']), str(i['location']), int(i['ref']), datetime.now()))
    doc_id = conn.execute("SELECT last_insert_rowid()").fetchone()[0]
    
    for j in i['word'].keys():
      word_id = conn.execute("SELECT id FROM words WHERE word = ?", (j,)).fetchone()
      if not word_id:
        conn.execute("INSERT INTO words (word) VALUES (?)", (j,))
        word_id = conn.execute("SELECT last_insert_rowid()").fetchone()[0]
      else:
        word_id = word_id[0]
      
      conn.execute('''INSERT INTO word_frequencies (word_id, doc_id, Frequency) VALUES (?, ?, ?);''', (word_id, doc_id, i['word'][j]))
  
 
  conn.commit()
  # update_tf_idf()

# %%
#เอาเพิ่ม
def temp_to_index():
    conn = sqlite3.connect('inverted_index.db')
    links = conn.execute('SELECT Link FROM temp_link ').fetchall()
    links = [t[0] for t in links]
    ref=get_ref()
    for i in links:
        doc = make_doc(i,ref)
        insert_to_database([doc])
        conn.execute('DELETE FROM temp_link WHERE link = ?; ', (i,))
        conn.commit()

# %%
temp_to_index()
# Out:
# {'link': 'http://www.bbc.com/news/av/10462520', 'title': 'One-minute World News - BBC News', 'body': "bbc homepageskip to contentaccessibility helpyour accounthomenewssportreelworklifetravelfuturemore menumore menusearch bbchomenewssportreelworklifetravelfutureculturemusictvweathersoundsclose menubbc newsmenuhomewar in ukrainecoronavirusclimatevideoworldasiaukbusinesstechmoresciencestoriesentertainment & artshealthworld news tvin picturesreality checknewsbeatlong readsone-minute world newsthis video can not be playedto play this video you need to enable javascript in your browser.one-minute world newsclosewatch the latest news summary from bbc world news. international news updated 24 hours a day.published3 hours agosectionbbc newsshareclose panelshare pagecopy linkabout sharingread descriptioneditor's recommendationsone-minute world news. video, 00:01:03one-minute world newspublished3 hours agosectionbbc news1:03up next. cctv shows ex-boxer amir khan robbed at gunpoint. video, 00:00:25cctv shows ex-boxer amir khan robbed at gunpointpublished12 hours agosubsectionlondonup next0:25football fans repeatedly throw chairs at police in naples. video, 00:00:35football fans repeatedly throw chairs at police in naplespublished13 hours agosubsectioneurope0:35truck washed away by huge flood in turkey quake zone. video, 00:00:43truck washed away by huge flood in turkey quake zonepublished13 hours agosubsectioneurope0:43nasa reveals new spacesuit for moon landing. video, 00:01:17nasa reveals new spacesuit for moon landingpublished12 hours agosubsectionus & canada1:17imran khan: look at the tear gas shells fired at my home. video, 00:00:24imran khan: look at the tear gas shells fired at my homepublished22 hours agosubsectionasia0:24pints, power and parents: budget info in 64 seconds. video, 00:01:04pints, power and parents: budget info in 64 secondspublished16 hours agosubsectionbusiness1:04baby kangaroo rescued from crocodile-infested waters. video, 00:00:32baby kangaroo rescued from crocodile-infested waterspublished1 day agosubsectionaustralia0:32'customers freaked': silicon valley bank saga in 80 seconds. video, 00:01:20'customers freaked': silicon valley bank saga in 80 secondspublished1 day agosubsectionus & canada1:20inside oscars a-list after-party. video, 00:01:05inside oscars a-list after-partypublished2 days agosubsectionentertainment & arts1:05homenewssportreelworklifetravelfutureculturemusictvweathersoundsterms of useabout the bbcprivacy policycookiesaccessibility helpparental guidancecontact the bbcget personalised newsletterswhy you can trust the bbcadvertise with usadchoices / do not sell my infoâ© 2023 bbc. the bbc is not responsible for the content of external sites. read about our approach to external linking.", 'location': ['None'], 'word': {'bbc': 4, 'homepageskip': 1, 'contentaccessibility': 1, 'helpyour': 1, 'accounthomenewssportreelworklifetravelfuturemore': 1, 'menumore': 1, 'menusearch': 1, 'bbchomenewssportreelworklifetravelfutureculturemusictvweathersoundsclose': 1, 'menubbc': 1, 'newsmenuhomewar': 1, 'ukrainecoronavirusclimatevideoworldasiaukbusinesstechmoresciencestoriesentertainment': 1, '&': 4, 'artshealthworld': 1, 'news': 5, 'tvin': 1, 'picturesreality': 1, 'checknewsbeatlong': 1, 'readsone': 1, '-': 12, 'minute': 4, 'world': 5, 'newsthis': 1, 'video': 12, 'playedto': 1, 'play': 1, 'need': 1, 'enable': 1, 'javascript': 1, 'browser.one': 1, 'newsclosewatch': 1, 'late': 1, 'summary': 1, 'international': 1, 'update': 1, '24': 1, 'hour': 8, 'day.published3': 1, 'agosectionbbc': 2, 'newsshareclose': 1, 'panelshare': 1, 'pagecopy': 1, 'linkabout': 1, 'sharingread': 1, 'descriptioneditor': 1, 'recommendationsone': 1, '00:01:03one': 1, 'newspublished3': 1, 'hours': 1, 'news1:03up': 1, 'cctv': 1, 'ex': 2, 'boxer': 2, 'amir': 2, 'khan': 4, 'rob': 2, 'gunpoint': 1, '00:00:25cctv': 1, 'gunpointpublished12': 1, 'agosubsectionlondonup': 1, 'next0:25football': 1, 'fan': 2, 'repeatedly': 2, 'throw': 2, 'chair': 2, 'police' ...
# {'link': 'http://www.bbc.com/news/topics/cq0jeeeqmndt', 'title': 'Global cost of living - BBC News', 'body': "bbc homepageskip to contentaccessibility helpyour accounthomenewssportreelworklifetravelfuturemore menumore menusearch bbchomenewssportreelworklifetravelfutureculturemusictvweathersoundsclose menubbc newsmenuhomewar in ukrainecoronavirusclimatevideoworldasiaukbusinesstechmoresciencestoriesentertainment & artshealthworld news tvin picturesreality checknewsbeatlong readsglobal cost of livingwhat is the ukraine grain deal and is it working?despite the war, ukraine has been able to export 23 million tonnes of grain since july 2022.attributionworldposted7 hours ago7hargentina inflation soars past 100% markattributionlatin america & caribbeanposted1 day ago1dindia farmers march in protest as onions rotattributionindiaposted1 day ago1d'i went into debt, trying to buy a miracle'attributionafricaposted4 days ago4dnigeria's chaotic banknote redesign ruled invalidattributionafricaposted3 march3 marcrucial bailout deal eludes cash-strapped pakistanattributionasiaposted10 february10 febvenezuela's slow economic recovery leaves poorest behindattributionlatin america & caribbeanposted4 february4 febinflation-hit argentina unveils higher-value noteattributionlatin america & caribbeanposted2 february2 febhow onions became a luxury in the philippinesattributionbusinessposted27 january27 janegyptians use loans to buy books as inflation soarsattributionmiddle eastposted25 january25 jannigeria cost-of-living crisis sparks exodus of doctorsattributionafricaposted30 january30 jandoes easing us inflation point the way for the world?attributionbusinessposted13 january13 janhow to make the most of cash stuffing - in a minute. video, 00:00:57how to make the most of cash stuffing - in a minuteattributionbusinessposted19 january19 jan0:57'there's a lot of suffering in ghana' video, 00:02:52'there's a lot of suffering in ghana'attributionafricaposted22 december 202222 dec 20222:52why some of brazil's poorest are drawn to lula. video, 00:03:06why some of brazil's poorest are drawn to lulaattributionlatin america & caribbeanposted26 october 202226 oct 20223:06india's middle class hit by rising cost of livingattributionbusinessposted14 december 202214 dec 2022croatia, the euro and a coffee controversyattributionbusinessposted19 january19 janwhy dutch 'bike banks' are a game changer for kidsattributionbusinessposted30 november 202230 nov 2022how are european countries tackling energy bills?attributionreality checkposted21 december 202221 dec 2022latest updates06:23the hidden cost of soothing my throat after cancer, published at 06:23the hidden cost of soothing my throat after cancerattributionglasgow & west scotland06:06parents put off more children over nursery costs, published at 06:06parents put off more children over nursery costsattributionwales19:23 15 march'i may still have to move back in with my parents', published at 19:23 15 march'i may still have to move back in with my parents'attributionbusiness17:13 15 marchwhat are teachers' pay demands?, published at 17:13 15 marchwhat are teachers' pay demands?attributionfamily & education16:13 15 marchwhat the budget means for you and your money, published at 16:13 15 marchwhat the budget means for you and your moneyattributionbusiness16:11 15 marchpints, power and parents: budget info in 64 seconds. video, 00:01:04, published at 16:11 15 marchpints, power and parents: budget info in 64 secondsattributionbusiness1:0415:35 15 marchwhen are the next university strikes?, published at 15:35 15 marchwhen are the next university strikes?attributionfamily & education14:48 15 marchhow are pension rules changing?, published at 14:48 15 marchhow are pension rules changing?attributionbusiness14:37 15 marchwho can get 30 hours of free childcare?, published at 14:37 15 marchwho can get 30 hours of free childcare?attributionfamily & education14:10 15 marchwhat does the budget mean for energy bills?, published at 1 ...
# {'link': 'http://www.bbc.com/news/england', 'title': 'England - BBC News', 'body': 'homepageaccessibility linksskip to contentaccessibility helpbbc accountnotificationshomenewssportweatheriplayersoundsbitesizecbeebiescbbcfoodhomenewssportreelworklifetravelfutureculturetvweathersoundsmore menu search bbc search bbc homenewssportweatheriplayersoundsbitesizecbeebiescbbcfoodhomenewssportreelworklifetravelfutureculturetvweathersoundsclose menu bbc newsnews navigationsectionshomewar in ukrainecoronavirusclimatevideoworldasiaukuk selectedbusinesstechsciencestoriesentertainment & artshealthworld news tvin picturesreality checknewsbeatlong readsmore more sectionsengland selectedregionsmore more sectionshomewar in ukrainecoronavirusclimatevideoworldworld homeafricaaustraliaeuropelatin americamiddle eastus & canadaasiaasia homechinaindiaukuk selecteduk homeenglandengland selectedn. irelandscotlandwalesisle of manguernseyjerseylocal newsbusinessbusiness homemarket datanew economynew tech economycompaniestechnology of businesseconomyceo secretsglobal tradecost of livingtechsciencestoriesentertainment & artshealthhealth homecoronavirusworld news tvin picturesreality checknewsbeatlong readsengland regions bbc news englandmurdered woman\'s family stunned by sentence decisionthe 23-year-old\'s family say her killer deserves a longer jail term before he is considered for release.1h33 minutes agoleicestertop storiesmurdered woman\'s family stunned by sentence decisionthe 23-year-old\'s family say her killer deserves a longer jail term before he is considered for release.1h33 minutes agoleicesterdoctors\' strike fallout could take weeks to resolvetens of thousands are likely to have been affected by a walkout in england, which ends on thursday morning.6h6 hours agohealthlivetax burden will be higher for a while, says huntlast updated7 minutes agomost recent posts7 minutes ago busy morning for hunt6mbusy morning for hunt16 minutes ago hunt hopes there will be nhs pay deal16mhunt hopes there will be nhs pay deal20 minutes ago hunt: tax burden will be higher for a while20mhunt: tax burden will be higher for a whilelive tax burden will be higher for a while, says hunt last updated 7 minutes agolivetax burden will be higher for a while, says huntstudent\'s hair claw clip warning after car crashjeena panesar\'s hair claw clip became lodged in her head during the crash in which her car flipped over.2h2 hours agoderbycctv of amir khan gunpoint robbery shown to courtthe former world boxing champion was forced to hand over his bespoke £72,000 watch in the footage.12h12 hours agolondon\'how opera changed my life after homelessness\'the production is designed to help participants gain confidence and rebuild their lives.2h2 hours agonottinghamwoman facing eviction from home of 62 yearsthe owner of anne marsh\'s home in nottinghamshire says it is no longer viable as a rental property.2h2 hours agonottinghamfeatured contentsmurdered woman\'s family stunned by sentence decisionthe 23-year-old\'s family say her killer deserves a longer jail term before he is considered for release.1h33 minutes agoleicesterdoctors\' strike fallout could take weeks to resolvetens of thousands are likely to have been affected by a walkout in england, which ends on thursday morning.6h6 hours agohealthlivetax burden will be higher for a while, says huntlast updated7 minutes agomost recent posts7 minutes ago busy morning for hunt6mbusy morning for hunt16 minutes ago hunt hopes there will be nhs pay deal16mhunt hopes there will be nhs pay deal20 minutes ago hunt: tax burden will be higher for a while20mhunt: tax burden will be higher for a whilelive tax burden will be higher for a while, says hunt last updated 7 minutes agolivetax burden will be higher for a while, says huntstudent\'s hair claw clip warning after car crashjeena panesar\'s hair claw clip became lodged in her head during the crash in which her car flipped over.2h2 hours agoderbycctv of amir khan gunpoint robbery shown to  ...
# {'link': 'http://www.bbc.com/news/world-asia-india-64936667', 'title': 'Maharashtra: India farmers march in protest as onions rot - BBC News', 'body': 'bbc homepageskip to contentaccessibility helpyour accounthomenewssportreelworklifetravelfuturemore menumore menusearch bbchomenewssportreelworklifetravelfutureculturemusictvweathersoundsclose menubbc newsmenuhomewar in ukrainecoronavirusclimatevideoworldasiaukbusinesstechmoresciencestoriesentertainment & artshealthworld news tvin picturesreality checknewsbeatlong readsasiachinaindiamaharashtra: india farmers march in protest as onions rotpublished1 day agoshareclose panelshare pagecopy linkabout sharingimage caption, onion farmers in maharashtra are demanding a better price for their cropfarmers in the western indian state of maharashtra have set out on a 200km (124-mile) march to mumbai, demanding higher prices for onions. the protests have prompted the authorities to announce some financial relief for onion growers. but farmers have rejected the proposal - and said they would continue their protest. bbc marathi\'s anagha pathak reports. at namdev thakare\'s vast family farm in nashik district, rows and rows of onions lie rotting. the farmer says he doesn\'t want to spend money to hire labourers to harvest the onions and take them to market because he can\'t recover the costs. he is among thousands of farmers in maharashtra who are protesting after onion prices suddenly crashed over the past few weeks. one of them burned his crop in desperation after sending an invitation to the state\'s chief minister others have posted parcels of onions to prime minister narendra modi in a bid to draw attention.onionomics: peeling away the layers of india\'s food economythis is something that occurs almost every other year. at around 24 million tonnes annually, india is the world\'s second-largest producer of onions, behind china. maharashtra accounts for more than half of this. about 10-15% of the countrywide produce is exported to other countries. image source, getty imagesimage caption, angry farmers have left their onions to rot in the fieldsonion prices in india are highly volatile. the vegetable is a staple part of the cuisine in most indian states and its perishability means it can\'t be stored for too long. onions can also be notoriously political - while a glut in supply can make prices fall, plunging thousands of farmers into crisis, a shortage can send prices soaring, sparking consumer anger that has even brought down governments in the past.officials say that a major reason for the latest crash in maharashtra was that demand from the populous northern states was dropping as the states of "uttar pradesh, bihar, rajasthan are also harvesting onions".why onions make india politicians cryshrikant kuwalekar, a farm expert, says that unexpected weather changes are also having an effect on production and hence prices.onions are cultivated during two seasons in india - monsoon and winter. the monsoon crop is usually harvested between late december and early january. these onions have a low shelf life and must reach markets quickly. the winter crop, harvested from mid-march, can be stored for a longer time."last year, there was heavy rainfall in the months of july-august, so farmers delayed their cultivation. this has led to a huge surplus of the onion crop in march, which would otherwise have hit the market in december-january," mr kuwalekar says, adding that things will get worse when the winter harvest also reaches the market in a few weeks.farmers in nashik say they are only getting around 200-400 rupees ($2.43-$4.85 â£2-â£4) per 100kg of onions in the wholesale market. image source, pravin thakre/bbc marathiimage caption, thousands are marching from nashik district to mumbaiajit navale, a farmer leader from maharashtra, explains the economics of onion farming. onion prices, he says, need to stay above 1,200 rupees per 100 kg if the farmer is to make at least 400 rupees of profit. whi ...
# {'link': 'http://www.bbc.com/news/localnews', 'title': 'Local News - BBC News', 'body': 'homepageaccessibility linksskip to contentaccessibility helpbbc accountnotificationshomenewssportweatheriplayersoundsbitesizecbeebiescbbcfoodhomenewssportreelworklifetravelfutureculturetvweathersoundsmore menu search bbc search bbc homenewssportweatheriplayersoundsbitesizecbeebiescbbcfoodhomenewssportreelworklifetravelfutureculturetvweathersoundsclose menu bbc newsnews navigationsectionshomehome selectedcost of livingwar in ukrainecoronavirusclimateukworldbusinesspoliticstechsciencehealthfamily & educationentertainment & artsin picturesnewsbeatreality checkdisabilitymore more sectionsenglandn. irelandscotlandalbawalescymrulocal newslocal news selectedmore more sectionshomehome selectedcost of livingwar in ukrainecoronavirusclimateukuk homeenglandn. irelandscotlandalbawalescymruisle of manguernseyjerseylocal newsworldworld homeafricaasiaaustraliaeuropelatin americamiddle eastus & canadabusinessbusiness homeyour moneymarket datacompanieseconomytechnology of businessceo secretsglobal tradepoliticspolitics homeparliamentsbrexittechsciencehealthfamily & educationfamily & education homeyoung reporterentertainment & artsin picturesnewsbeatreality checkdisability get the news that’s local to you news navigationsectionssectionshomehome selectedcost of livingwar in ukrainecoronavirusclimateukuk homeenglandn. irelandscotlandalbawalescymruisle of manguernseyjerseylocal newsworldworld homeafricaasiaaustraliaeuropelatin americamiddle eastus & canadabusinessbusiness homeyour moneymarket datacompanieseconomytechnology of businessceo secretsglobal tradepoliticspolitics homeparliamentsbrexittechsciencehealthfamily & educationfamily & education homeyoung reporterentertainment & artsin picturesnewsbeatreality checkdisability bbc news serviceson your mobileon smart speakersget news alertscontact bbc news explore the bbchomenewssportweatheriplayersoundsbitesizecbeebiescbbcfoodhomenewssportreelworklifetravelfutureculturetvweathersoundsterms of useabout the bbcprivacy policycookiesaccessibility helpparental guidancecontact the bbcmake an editorial complaintbbc emails for youadvertise with usadchoices / do not sell my infocopyright © 2023 bbc. the bbc is not responsible for the content of external sites. read about our approach to external linking.', 'location': ['None'], 'word': {'homepageaccessibility': 1, 'linksskip': 1, 'contentaccessibility': 1, 'helpbbc': 1, 'accountnotificationshomenewssportweatheriplayersoundsbitesizecbeebiescbbcfoodhomenewssportreelworklifetravelfutureculturetvweathersoundsmore': 1, 'menu': 2, 'search': 2, 'bbc': 7, 'homenewssportweatheriplayersoundsbitesizecbeebiescbbcfoodhomenewssportreelworklifetravelfutureculturetvweathersoundsclose': 1, 'newsnews': 1, 'navigationsectionshomehome': 1, 'selectedcost': 3, 'livingwar': 3, 'ukrainecoronavirusclimateukworldbusinesspoliticstechsciencehealthfamily': 1, '&': 10, 'educationentertainment': 1, 'artsin': 3, 'picturesnewsbeatreality': 3, 'checkdisabilitymore': 1, 'sectionsenglandn': 1, 'irelandscotlandalbawalescymrulocal': 1, 'newslocal': 1, 'news': 6, 'selectedmore': 1, 'sectionshomehome': 1, 'ukrainecoronavirusclimateukuk': 2, 'homeenglandn': 2, 'irelandscotlandalbawalescymruisle': 2, 'manguernseyjerseylocal': 2, 'newsworldworld': 2, 'homeafricaasiaaustraliaeuropelatin': 2, 'americamiddle': 2, 'eastus': 2, 'canadabusinessbusiness': 2, 'homeyour': 2, 'moneymarket': 2, 'datacompanieseconomytechnology': 2, 'businessceo': 2, 'secretsglobal': 2, 'tradepoliticspolitic': 2, 'homeparliamentsbrexittechsciencehealthfamily': 2, 'educationfamily': 2, 'education': 2, 'homeyoung': 2, 'reporterentertainment': 2, 'checkdisability': 2, '’': 1, 'local': 1, 'navigationsectionssectionshomehome': 1, 'serviceson': 1, 'mobileon': 1, 'smart': 1, 'speakersget': 1, 'alertscontact': 1, 'explore': 1, 'bbchomenewssportweatheriplayersoundsbitesizecbeebiescbbcfoodhomenewssportreelworklifetravelfutureculturetvweathersoundsterm ...
# {'link': 'http://www.bbc.com/news/world/us_and_canada', 'title': 'US & Canada - BBC News', 'body': "homepageaccessibility linksskip to contentaccessibility helpbbc accountnotificationshomenewssportweatheriplayersoundsbitesizecbeebiescbbcfoodhomenewssportreelworklifetravelfutureculturetvweathersoundsmore menu search bbc search bbc homenewssportweatheriplayersoundsbitesizecbeebiescbbcfoodhomenewssportreelworklifetravelfutureculturetvweathersoundsclose menu bbc newsnews navigationsectionshomewar in ukrainecoronavirusclimatevideoworldworld selectedasiaukbusinesstechsciencestoriesentertainment & artshealthworld news tvin picturesreality checknewsbeatlong readsmore more sectionsworld selectedafricaaustraliaeuropelatin americamiddle eastus & canadaus & canada selectedmore more sectionshomewar in ukrainecoronavirusclimatevideoworldworld selectedworld homeafricaaustraliaeuropelatin americamiddle eastus & canadaus & canada selectedasiaasia homechinaindiaukuk homeenglandn. irelandscotlandwalesisle of manguernseyjerseylocal newsbusinessbusiness homemarket datanew economynew tech economycompaniestechnology of businesseconomyceo secretsglobal tradecost of livingtechsciencestoriesentertainment & artshealthhealth homecoronavirusworld news tvin picturesreality checknewsbeatlong readsworld africaaustraliaeuropelatin americamiddle eastus & canadaus & canada selectedus & canada bbc news us & canadaus accuses chinese tycoon of billion-dollar fraudas part of the inquiry into guo wengui, the us seizes more than $630m from multiple bank accounts.8h8 hours agous & canadatop storiesus accuses chinese tycoon of billion-dollar fraudas part of the inquiry into guo wengui, the us seizes more than $630m from multiple bank accounts.8h8 hours agous & canadatexas judge considers banning abortion pill in usthe drug, mifepristone, can be taken at home and is used in more than half of us abortions.12h12 hours agous & canadais the world prepared for the coming ai storm?artificial intelligence will radically change our lives, for better and worse. experts are worried.8h8 hours agous & canadatiktok says us threatens ban if china stake not soldtiktok, owned by chinese firm bytedance, says it has been contacted about a change in ownership.5h5 hours agotechnologyseven us deputies charged with murder of man in custodyprosecutors accuse the deputies of suffocating 28-year-old irvo otieno earlier this month.7h7 hours agous & canada'big ugly diamond' discovered by us park visitorit's large, but not as large as other diamonds visitors have found in this unique crater.8h8 hours agous & canadasan francisco could award some black residents $5munder the reparations plan, the city is also considering homes in san francisco for $1 per family.15h15 hours agous & canadafeatured contentsus accuses chinese tycoon of billion-dollar fraudas part of the inquiry into guo wengui, the us seizes more than $630m from multiple bank accounts.8h8 hours agous & canadatexas judge considers banning abortion pill in usthe drug, mifepristone, can be taken at home and is used in more than half of us abortions.12h12 hours agous & canadais the world prepared for the coming ai storm?artificial intelligence will radically change our lives, for better and worse. experts are worried.8h8 hours agous & canadatiktok says us threatens ban if china stake not soldtiktok, owned by chinese firm bytedance, says it has been contacted about a change in ownership.5h5 hours agotechnologyseven us deputies charged with murder of man in custodyprosecutors accuse the deputies of suffocating 28-year-old irvo otieno earlier this month.7h7 hours agous & canada'big ugly diamond' discovered by us park visitorit's large, but not as large as other diamonds visitors have found in this unique crater.8h8 hours agous & canadasan francisco could award some black residents $5munder the reparations plan, the city is also considering homes in san francisco for $1 per family.15h15 hours agous & canadatexas judge considers banning abortion ...
# {'link': 'http://www.bbc.com/news/business/economy', 'title': 'Economy - BBC News', 'body': 'homepageaccessibility linksskip to contentaccessibility helpbbc accountnotificationshomenewssportweatheriplayersoundsbitesizecbeebiescbbcfoodhomenewssportreelworklifetravelfutureculturetvweathersoundsmore menu search bbc search bbc homenewssportweatheriplayersoundsbitesizecbeebiescbbcfoodhomenewssportreelworklifetravelfutureculturetvweathersoundsclose menu bbc newsnews navigationsectionshomewar in ukrainecoronavirusclimatevideoworldasiaukbusinessbusiness selectedtechsciencestoriesentertainment & artshealthworld news tvin picturesreality checknewsbeatlong readsmore more sectionsbusiness selectedmarket datanew economynew tech economycompaniestechnology of businesseconomyeconomy selectedceo secretsglobal tradecost of livingmore more sectionshomewar in ukrainecoronavirusclimatevideoworldworld homeafricaaustraliaeuropelatin americamiddle eastus & canadaasiaasia homechinaindiaukuk homeenglandn. irelandscotlandwalesisle of manguernseyjerseylocal newsbusinessbusiness selectedbusiness homemarket datanew economynew tech economycompaniestechnology of businesseconomyeconomy selectedceo secretsglobal tradecost of livingtechsciencestoriesentertainment & artshealthhealth homecoronavirusworld news tvin picturesreality checknewsbeatlong readsbusiness market datanew economynew tech economycompaniestechnology of businesseconomyeconomy selectedceo secretsglobal tradecost of livingeconomy bbc news economyuk faces biggest fall in spending power for 70 yearsthe gloomy forecast came as chancellor jeremy hunt delivered his budget in the commons.12h12 hours agobusinessrelated contentbudget 2023: key points at-a-glanceenergy bill help to continue until end of junerelated contentbudget 2023: key points at-a-glanceenergy bill help to continue until end of junetop storiesuk faces biggest fall in spending power for 70 yearsthe gloomy forecast came as chancellor jeremy hunt delivered his budget in the commons.12h12 hours agobusinessrelated contentbudget 2023: key points at-a-glanceenergy bill help to continue until end of june\'i may still have to move back in with my parents\'young people tell the bbc what they think of the help announced in the spring budget.13h13 hours agobusinessargentina inflation soars past 100% markinflation hits triple digits for the first time since the period of hyperinflation in the early 1990s.1da day agolatin america & caribbeanuk job vacancies fall for eighth time in a rowthe number of jobs on offer drops as the chancellor prepares to set out plans to get people back to work.1da day agobusinesswarning that us banks face more painthe ratings giant warns of a \'rapid deterioration in the operating environment\' for us banks.1da day agobusiness commentsrising interest rates will uncover more ticking bombsrapid rate rises were always likely to lead to unintended consequences in the financial system.3d3 days agobusinessconfidence returning as economy rebounds - sunakthe economy grew by more than expected in january, helped by higher school attendance.5d5 days agobusinessfeatured contentsuk faces biggest fall in spending power for 70 yearsthe gloomy forecast came as chancellor jeremy hunt delivered his budget in the commons.12h12 hours agobusinessrelated contentbudget 2023: key points at-a-glanceenergy bill help to continue until end of junerelated contentbudget 2023: key points at-a-glanceenergy bill help to continue until end of june\'i may still have to move back in with my parents\'young people tell the bbc what they think of the help announced in the spring budget.13h13 hours agobusinessargentina inflation soars past 100% markinflation hits triple digits for the first time since the period of hyperinflation in the early 1990s.1da day agolatin america & caribbeanuk job vacancies fall for eighth time in a rowthe number of jobs on offer drops as the chancellor prepares to set out plans to get people back to work.1da day agobusinesswarning t ...
# {'link': 'http://www.bbc.com/news/world-asia-india-64813501', 'title': "Abhimaan: A Bollywood marital drama that's relevant even after 50 years - BBC News", 'body': 'bbc homepageskip to contentaccessibility helpyour accounthomenewssportreelworklifetravelfuturemore menumore menusearch bbchomenewssportreelworklifetravelfutureculturemusictvweathersoundsclose menubbc newsmenuhomewar in ukrainecoronavirusclimatevideoworldasiaukbusinesstechmoresciencestoriesentertainment & artshealthworld news tvin picturesreality checknewsbeatlong readsasiachinaindiaabhimaan: a bollywood marital drama that\'s relevant even after 50 yearspublished6 hours agoshareclose panelshare pagecopy linkabout sharingimage source, smm ausaja archiveby geeta pandeybbc news, delhias the 1973 bollywood hit film abhimaan, with superstar amitabh bachchan and his wife jaya in the lead, turns 50 this year, the bbc examines the enduring charm and impact of this movie. amitabh bachchan is best-known for his role as the angry young man of bollywood who starred in such iconic films as deewar, zanjeer and sholay.but many consider abhimaan (pride) - the musical drama about the fragility of human relationships - to be among his finest roles.the actor plays a popular singer who convinces his new wife to join him on stage, but his ego is hurt and jealousy takes over when she outshines him. director hrishikesh mukherjee paired bachchan with his wife jaya - the couple were in love and had married just a month before its release - and she won the prestigious filmfare award for best actress for her performance. abhimaan, which completes half a century in july, has a special significance for me - it was the first-ever bachchan film i saw and it remains my favourite of all his films even today. it was among more than half a dozen bachchan films to release that year. the list included saudagar, which was india\'s official oscar entry that year, and zanjeer, the blockbuster which established him as india\'s top action hero. but film critic and author saibal chatterjee told the bbc that "abhimaan was the most talked about film of the year" and "his biggest hit that year".fans visited cinemas in droves, entire families including parents and young children packed theatres, crowding the matinee and evening shows.theatre actress and a self-confessed "huge bachchan fan" monisha bhaskar says the "evergreen story" of the envious husband unhappy at the success of his wife touched a chord with the audiences "because it is rooted in reality"."abhimaan\'s story was very believable because ego often comes between a couple, especially in a society like india where most men are uncomfortable with their wives doing better."image source, smm ausaja archive"ironically," she says, "it was he who first encouraged her to sing, but then couldn\'t handle it when she became more popular than him. but she was not competing with him, she was just more gifted."ms bhaskar, who was four when her parents took her to watch the film when it released, in a delhi cinema, has revisited it several times since. "of course i didn\'t understand it the first time, but i enjoyed the music and the songs. i\'ve watched it many times since then and i\'ve loved it each time a bit more," she told me.ms bhaskar considers the role to be among "bachchan\'s finest performances" and says that jaya, as the suffering wife, was "very believable" and the "music was fabulous and the songs took the story forward".amitabh bachchan as you\'ve never seen him beforewhy amitabh bachchan is more than a superstarover the years, abhimaan has won high praise from fans, critics and bachchan couple\'s colleagues in the film industry.filmmaker karan johar has called it "one of my favourite films" and says he cries "every time i see it". a few years back, actress vidya balan confessed to watching it for the "nth time" and described it as a "timeless" film. in december 2022, the kolkata international film festival kicked off with this classic. bachchan hi ...
# {'link': 'http://www.bbc.com/news/world', 'title': 'World - BBC News', 'body': 'homepageaccessibility linksskip to contentaccessibility helpbbc accountnotificationshomenewssportweatheriplayersoundsbitesizecbeebiescbbcfoodhomenewssportreelworklifetravelfutureculturetvweathersoundsmore menu search bbc search bbc homenewssportweatheriplayersoundsbitesizecbeebiescbbcfoodhomenewssportreelworklifetravelfutureculturetvweathersoundsclose menu bbc newsnews navigationsectionshomewar in ukrainecoronavirusclimatevideoworldworld selectedasiaukbusinesstechsciencestoriesentertainment & artshealthworld news tvin picturesreality checknewsbeatlong readsmore more sectionsworld selectedafricaaustraliaeuropelatin americamiddle eastus & canadamore more sectionshomewar in ukrainecoronavirusclimatevideoworldworld selectedworld homeworld selectedafricaaustraliaeuropelatin americamiddle eastus & canadaasiaasia homechinaindiaukuk homeenglandn. irelandscotlandwalesisle of manguernseyjerseylocal newsbusinessbusiness homemarket datanew economynew tech economycompaniestechnology of businesseconomyceo secretsglobal tradecost of livingtechsciencestoriesentertainment & artshealthhealth homecoronavirusworld news tvin picturesreality checknewsbeatlong readsworld africaaustraliaeuropelatin americamiddle eastus & canada bbc news world0:57video 57 secondsrussian casualties mount in bakhmut, but tactics evolvethe bbc has been given access to positions held by ukrainian army brigades defending bakhmut\'s southern flank.2h2 hours agoeuroperelated contentwhy bakhmut matters for russia and ukraineheavy losses reported as battle for bakhmut ragesthe devastated towns near ukraine\'s front linerelated contentwhy bakhmut matters for russia and ukraineheavy losses reported as battle for bakhmut ragesthe devastated towns near ukraine\'s front linetop stories0:57video 57 secondsrussian casualties mount in bakhmut, but tactics evolvethe bbc has been given access to positions held by ukrainian army brigades defending bakhmut\'s southern flank.2h2 hours agoeuroperelated contentwhy bakhmut matters for russia and ukraineheavy losses reported as battle for bakhmut ragesthe devastated towns near ukraine\'s front linen korea fires long range missile ahead of japan talksthe icbm marks pyongyang\'s fourth round of launches in a week as south korea and japan leaders meet.5h5 hours agoasiaevacuated afghan team included \'false\' footballerswomen footballers evacuated to the uk included some who were not the top players it was claimed.2h2 hours agoworldfarmer\'s protest party win shock dutch vote victorythe movement was only set up in 2019 and is on course to become the biggest party in the senate.18m19 minutes agoeuropetonnes of uranium gone missing in libya - unun inspectors are trying to locate around two and a half tonnes of uranium ore.1han hour agoafricatiktok says us threatens ban if china stake not soldtiktok, owned by chinese firm bytedance, says it has been contacted about a change in ownership.5h5 hours agotechnologysix held over sydney man\'s torture-kidnap ordealpolice say the 26-year-old victim had teeth forcibly removed after being kidnapped for ransom.5h5 hours agoaustraliafeatured contents0:57video 57 secondsrussian casualties mount in bakhmut, but tactics evolvethe bbc has been given access to positions held by ukrainian army brigades defending bakhmut\'s southern flank.2h2 hours agoeuroperelated contentwhy bakhmut matters for russia and ukraineheavy losses reported as battle for bakhmut ragesthe devastated towns near ukraine\'s front linerelated contentwhy bakhmut matters for russia and ukraineheavy losses reported as battle for bakhmut ragesthe devastated towns near ukraine\'s front linen korea fires long range missile ahead of japan talksthe icbm marks pyongyang\'s fourth round of launches in a week as south korea and japan leaders meet.5h5 hours agoasiaevacuated afghan team included \'false\' footballerswomen footballers evacuated to the uk included some who were not  ...
# {'link': 'http://www.bbc.com/news/world-us-canada-64894524', 'title': "Maple syrup's bittersweet future in face of climate change - BBC News", 'body': "bbc homepageskip to contentaccessibility helpyour accounthomenewssportreelworklifetravelfuturemore menumore menusearch bbchomenewssportreelworklifetravelfutureculturemusictvweathersoundsclose menubbc newsmenuhomewar in ukrainecoronavirusclimatevideoworldasiaukbusinesstechmoresciencestoriesentertainment & artshealthworld news tvin picturesreality checknewsbeatlong readsworldafricaaustraliaeuropelatin americamiddle eastus & canadamaple syrup's bittersweet future in face of climate changethis video can not be playedto play this video you need to enable javascript in your browser.maple syrup's bittersweet future in face of climate changecloseincreasingly unpredictable winter temperatures are having a substantial effect on the maple syrup industry across the maple belt. michael parker and his wife, laure trudeau, don't know if their children will get the chance to grow up on a maple farm like they did.video by eloise alanapublished6 hours agosectionbbc newssubsectionus & canadashareclose panelshare pagecopy linkabout sharingread descriptionexplore moreclimate change impact on maple syrup production. video, 00:01:36climate change impact on maple syrup productionpublished6 hours agosubsectionus & canada1:36up next. china must act on climate change - attenborough. video, 00:02:00china must act on climate change - attenboroughpublished16 january 2020subsectionscience & environmentup next2:00what is climate change? video, 00:03:14what is climate change?published12 december 2020subsectionscience & environment3:14editor's recommendationscctv shows ex-boxer amir khan robbed at gunpoint. video, 00:00:25cctv shows ex-boxer amir khan robbed at gunpointpublished11 hours agosubsectionlondon0:25football fans repeatedly throw chairs at police in naples. video, 00:00:35football fans repeatedly throw chairs at police in naplespublished12 hours agosubsectioneurope0:35truck washed away by huge flood in turkey quake zone. video, 00:00:43truck washed away by huge flood in turkey quake zonepublished12 hours agosubsectioneurope0:43nasa reveals new spacesuit for moon landing. video, 00:01:17nasa reveals new spacesuit for moon landingpublished10 hours agosubsectionus & canada1:17imran khan: look at the tear gas shells fired at my home. video, 00:00:24imran khan: look at the tear gas shells fired at my homepublished21 hours agosubsectionasia0:24pints, power and parents: budget info in 64 seconds. video, 00:01:04pints, power and parents: budget info in 64 secondspublished14 hours agosubsectionbusiness1:04one-minute world news. video, 00:01:03one-minute world newspublished2 hours agosectionbbc news1:03baby kangaroo rescued from crocodile-infested waters. video, 00:00:32baby kangaroo rescued from crocodile-infested waterspublished1 day agosubsectionaustralia0:32'customers freaked': silicon valley bank saga in 80 seconds. video, 00:01:20'customers freaked': silicon valley bank saga in 80 secondspublished1 day agosubsectionus & canada1:20inside oscars a-list after-party. video, 00:01:05inside oscars a-list after-partypublished2 days agosubsectionentertainment & arts1:05homenewssportreelworklifetravelfutureculturemusictvweathersoundsterms of useabout the bbcprivacy policycookiesaccessibility helpparental guidancecontact the bbcget personalised newsletterswhy you can trust the bbcadvertise with usadchoices / do not sell my infoâ© 2023 bbc. the bbc is not responsible for the content of external sites. read about our approach to external linking.", 'location': ['china'], 'word': {'bbc': 3, 'homepageskip': 1, 'contentaccessibility': 1, 'helpyour': 1, 'accounthomenewssportreelworklifetravelfuturemore': 1, 'menumore': 1, 'menusearch': 1, 'bbchomenewssportreelworklifetravelfutureculturemusictvweathersoundsclose': 1, 'menubbc': 1, 'newsmenuhomewar': 1, 'ukrainecoronavirusclimatevideoworldasiaukbusinesstechmoresciencestori ...
# {'link': 'http://www.bbc.com/news/world/asia', 'title': 'Asia - BBC News', 'body': 'homepageaccessibility linksskip to contentaccessibility helpbbc accountnotificationshomenewssportweatheriplayersoundsbitesizecbeebiescbbcfoodhomenewssportreelworklifetravelfutureculturetvweathersoundsmore menu search bbc search bbc homenewssportweatheriplayersoundsbitesizecbeebiescbbcfoodhomenewssportreelworklifetravelfutureculturetvweathersoundsclose menu bbc newsnews navigationsectionshomewar in ukrainecoronavirusclimatevideoworldasiaasia selectedukbusinesstechsciencestoriesentertainment & artshealthworld news tvin picturesreality checknewsbeatlong readsmore more sectionsasia selectedchinaindiamore more sectionshomewar in ukrainecoronavirusclimatevideoworldworld homeafricaaustraliaeuropelatin americamiddle eastus & canadaasiaasia selectedasia homeasia selectedchinaindiaukuk homeenglandn. irelandscotlandwalesisle of manguernseyjerseylocal newsbusinessbusiness homemarket datanew economynew tech economycompaniestechnology of businesseconomyceo secretsglobal tradecost of livingtechsciencestoriesentertainment & artshealthhealth homecoronavirusworld news tvin picturesreality checknewsbeatlong readsasia chinaindia bbc news asias korea and japan: a milestone meeting of frenemiesbbc correspondents explain why historic rivals are trying to rebuild trust - and who stands to gain.7h7 hours agoasiarelated contentn korea fires long range missile ahead of japan talksthe sex slave who refused to be silenced\'comfort women\' - a painful legacyrelated contentn korea fires long range missile ahead of japan talksthe sex slave who refused to be silenced\'comfort women\' - a painful legacytop storiess korea and japan: a milestone meeting of frenemiesbbc correspondents explain why historic rivals are trying to rebuild trust - and who stands to gain.7h7 hours agoasiarelated contentn korea fires long range missile ahead of japan talksthe sex slave who refused to be silenced\'comfort women\' - a painful legacyn korea fires long range missile ahead of japan talksthe icbm marks pyongyang\'s fourth round of launches in a week as south korea and japan leaders meet.5h5 hours agoasiasix held over sydney man\'s torture-kidnap ordealpolice say the 26-year-old victim had teeth forcibly removed after being kidnapped for ransom.5h5 hours agoaustraliaevacuated afghan women\'s team included \'false\' footballers women footballers evacuated to the uk included some who were not the top players it was claimed.2h2 hours agoworldtiktok says us threatens ban if china stake not soldtiktok, owned by chinese firm bytedance, says it has been contacted about a change in ownership.5h5 hours agotechnologywhy vietnam doesn\'t want to claim ke huy quanthe actor has openly acknowledged his vietnamese roots but the reaction to his historic win has been muted.9h9 hours agoasiaimran khan greets supporters after police withdrawofficers leave the home of pakistan\'s main opposition leader after they tried to arrest him.16h16 hours agoasiafeatured contentss korea and japan: a milestone meeting of frenemiesbbc correspondents explain why historic rivals are trying to rebuild trust - and who stands to gain.7h7 hours agoasiarelated contentn korea fires long range missile ahead of japan talksthe sex slave who refused to be silenced\'comfort women\' - a painful legacyrelated contentn korea fires long range missile ahead of japan talksthe sex slave who refused to be silenced\'comfort women\' - a painful legacyn korea fires long range missile ahead of japan talksthe icbm marks pyongyang\'s fourth round of launches in a week as south korea and japan leaders meet.5h5 hours agoasiasix held over sydney man\'s torture-kidnap ordealpolice say the 26-year-old victim had teeth forcibly removed after being kidnapped for ransom.5h5 hours agoaustraliaevacuated afghan women\'s team included \'false\' footballers women footballers evacuated to the uk included some who were not the top players it was claimed.2h2 hours agowo ...
# ...
# {'link': 'http://www.thairath.co.th/tv/program/Setthee_Pai_Deang/726831', 'title': '“ข้าวซอยมาดามแอน” สูตรล้านนาแท้ๆ จากเชียงใหม่ ยอดขาย 150 ชาม/วัน | เศรษฐีป้ายแดง EP.154', 'body': ['ดูย้อนหลังรายการผังรายการliveเข้าสู่ระบบสมัครสมาชิกหน้าแรกรายการผังรายการผู้ประกาศliveหมวดวิดีโอดูย้อนหลังวาไรตี้บันเทิงข่าวไทยรัฐกีฬาไทยรัฐออนไลน์facebooktwitterติดต่อโฆษณาสมัครงานติดต่อสอบถาม 26 ก.พ. 2566 18:00 น.“ข้าวซอยมาดามแอน” สูตรล้านนาแท้ๆ จากเชียงใหม่ ยอดขาย 150 ชาม/วัน | เศรษฐีป้ายแดง ep.154ดูย้อนหลัง “เศรษฐีป้ายแดง”ดูทั้งหมด“จุ่มลาดหญ้าหน้าสหกรณ์” ขายจนซื้อตึกด้วยเงินสดราคา 6 ล้านบาทได้ | เศรษฐีป้ายแดง ep.156“แอนท่าดินแดง” ร้านระดับตำนานเรื่องอาหารทะเล | เศรษฐีป้ายแดง ep.155เจาะตำนานความอร่อย “เสี่ยวหลงเปา” ขั้นเทพ ขายได้ 1,600 ลูกต่อวัน! | เศรษฐีป้ายแดง ep.153เปิดสูตรลับ “เจ้เจียน โจ๊กนางเลิ้ง” ร้านอร่อยริมทาง ย่านนางเลิ้ง | เศรษฐีป้ายแดง ep.152ดูทั้งหมดติดต่อโฆษณาสมัครงานติดต่อสอบถามสงวนลิขสิทธิ์ © บริษัท ทริปเปิล วี บรอดคาสท์ จำกัดนโยบายคุ้มครองข้อมูลส่วนบุคคลไทยรัฐกรุ๊ปเงื่อนไขข้อตกลงการใช้บริการfacebooktwitteryoutube '], 'location': 'Thailand', 'word': {'ดู': 5, 'ย้อนหลัง': 3, 'รายการ': 4, 'ผัง': 2, 'live': 2, 'เข้าสู่ระบบ': 1, 'สมัคร': 1, 'สมาชิก': 1, 'หน้า': 2, 'แรก': 1, 'ผู้ประกาศ': 1, 'หมวด': 1, 'วิดีโอ': 1, 'วาไรตี้': 1, 'บันเทิง': 1, 'ข่าว': 1, 'ไทยรัฐ': 3, 'กีฬา': 1, 'ออนไลน์': 1, 'facebooktwitter': 1, 'ติดต่อ': 2, 'โฆษณา': 2, 'สมัครงาน': 2, 'ติดต่อสอบถาม': 2, '26': 1, 'ก.พ.': 1, '2566': 1, '18:00': 1, 'น.': 1, '“': 6, 'ข้าวซอย': 1, 'มาดาม': 1, 'แอน': 2, '”': 6, 'สูตร': 2, 'ล้านนา': 1, 'แท้ๆ': 1, 'จาก': 1, 'เชียงใหม่': 1, 'ยอดขาย': 1, '150': 1, 'ชาม': 1, '/': 1, 'วัน': 2, '|': 5, 'เศรษฐี': 6, 'ป้าย': 6, 'แดง': 6, 'ep': 5, '.': 5, '154': 1, 'ทั้งหมด': 2, 'จุ่ม': 1, 'ลาด': 1, 'หญ้า': 1, 'สหกรณ์': 1, 'ขาย': 2, 'จน': 1, 'ซื้อ': 1, 'ตึก': 1, 'ด้วย': 1, 'เงินสด': 1, 'ราคา': 1, '6': 1, 'ล้าน': 1, 'บาท': 1, 'ได้': 2, '156': 1, 'ท่า': 1, 'ดินแดง': 1, 'ร้าน': 2, 'ระดับ': 1, 'ตำนาน': 2, 'เรื่อง': 1, 'อาหารทะเล': 1, '155': 1, 'เจาะ': 1, 'ความ': 1, 'อร่อย': 2, 'เสี่ยว': 1, 'หลง': 1, 'เปา': 1, 'ขั้น': 1, 'เทพ': 1, '1,600': 1, 'ลูก': 1, 'ต่อ': 1, '!': 1, '153': 1, 'เปิด': 1, 'ลับ': 1, 'เจ้': 1, 'เจียน': 1, 'โจ๊ก': 1, 'นางเลิ้ง': 2, 'ริม': 1, 'ทาง': 1, 'ย่าน': 1, '152': 1, 'สงวนลิขสิทธิ์': 1, '©': 1, 'บริษัท': 1, 'ทริป': 1, 'เปิล': 1, 'วี': 1, 'บรอดคาสท์': 1, 'จำกัด': 1, 'นโยบาย': 1, 'คุ้มครอง': 1, 'ข้อมูล': 1, 'ส่วนบุคคล': 1, 'กรุ๊ป': 1, 'เงื่อนไข': 1, 'ข้อตกลง': 1, 'การ': 1, 'ใช้': 1, 'บริการ': 1, 'facebooktwitteryoutube': 1}, 'ref': 0}
# {'link': 'http://www.thairath.co.th/multimedia/gallery/entertain/news/34380', 'title': '"บัว-นลินทิพย์" ฉีกทุกบทบาทที่เคยได้รับ ในละคร “มณีพยาบาท”', 'body': ['ไทยรัฐ สำนักข่าวอันดับ 1 ของไทย | ไทยรัฐออนไลน์ไทยรัฐออนไลน์ข่าวพระราชสำนักทั่วไทยในกระแสการเมืองเศรษฐกิจต่างประเทศอาชญากรรมยานยนต์เทคโนโลยีราคาทองคำรายงานพิเศษวิดีโอหนังสือพิมพ์ไทยรัฐทีวีดูย้อนหลังผังรายการliveไลฟ์สไตล์กีฬาฟุตบอลต่างประเทศฟุตบอลไทยsport insiderไฟต์สปอร์ตกีฬาโลกวิดีโอแกลเลอรี่ฟุตบอลโลก 2022บันเทิงดวงหวยนิยายโปรโมชั่นซื้อ-ขายส่วนลดเช็คราคาthairathplusliveliveเข้าสู่ระบบสมัครสมาชิกค้นหาhamburgerhamburgerค้นหาthairath membershipเข้าสู่ระบบสมัครสมาชิกlive ชมรายการสดข่าวbackข่าวข่าวล่าสุดพระราชสำนักทั่วไทยในกระแสการเมืองเศรษฐกิจต่างประเทศอาชญากรรมยานยนต์เทคโนโลยีราคาทองคำรายงานพิเศษกีฬาbackฟุตบอลต่างประเทศฟุตบอลไทยsport insiderไฟต์สปอร์ตกีฬาโลกวิดีโอแกลเลอรี่ฟุตบอลโลก 2022ไทยรัฐทีวีbackดูย้อนหลังวาไรตี้บันเทิงกีฬาผังรายการliveโปรโมชั่นbackโปรโมชั่นซื้อ-ขายส่วนลดเช็คราคาthairath talkหนังสือพิมพ์คอลัมน์บันเทิงดวงหวยนิยายวิดีโอpodcastไลฟ์สไตล์กิจกรรมthairath plusbackthairath plusspeakmoneyeveryday lifenature mattersubculturefuturismsparkmirrorbackmirror100 ปี ชาตกาล  กำพล วัชรพลร่วมงานกับเราเกี่ยวกับเราติดต่อเราติดต่อโฆษณาfacebookfacebooktwittertwitterinstagraminstagramyoutubeyoutubeบันเทิงแกลเลอรี่infographicไทยรัฐออนไลน์มัลติมีเดียแกลเลอรี่บันเทิง"บัว-นลินทิพย์" ฉีกทุกบทบาทที่เคยได้รับ ในละคร “มณีพยาบาท”โดย ไทยรัฐออนไลน์16 ภาพ11 มี.ค. 2566 16:05\xa0ฉีกทุกบทบาทที่เคยได้รับ นางเอกสาวหน้าหวานตาโต "บัว-นลินทิพย์ สกุลอ่องอำไพ” เสิร์ฟความปัง!! ในผลงานเรื่องแรกที่ถ่ายทำ หลังผันตัวมาเป็นนักแสดงอิสระกับละคร “มณีพยาบาท” ทางช่องวัน 31 จับคู่พระเอกหน้าใส “นิว–ฐิติภูมิ เตชะอภัยคุณ” ถ่ายทอดบทสุดท้าทาย กับความรักในทุกภพ ทุกชาติ ที่เต็มไปด้วยอุปสรรค ความระทึก สุดเข้มข้น ที่เต็มไปด้วยแรงอาฆาต ร่วมด้วย “เบญ–เรวิญานันท์ ทาเกิด” สวมบทวิญญาณสาวตามรังควานไม่ได้หยุดหย่อน เดินทางมาถึงโค้งสุดท้ายใกล้ลงเอย เรื่องนี้ “บัว” บอกเลยว่าคือที่สุดในชีวิตแล้วแท็กที่เกี่ยวข้องบัว นลินทิพย์มณีพยาบาทนักแสดงอิสระนิว ฐิติภูมิมาลัยไทยรัฐ'], 'location': 'Thailand', 'word': {'ไทยรัฐ': 8, 'สำนักข่าว': 1, 'อันดับ': 1, '1': 1, 'ของ': 1, 'ไทย': 5, '|': 1, 'ออนไลน์': 4, 'ข่าว': 4, 'พระ': 2, 'ราชสำนัก': 2, 'ทั่ว': 2, 'ใน': 6, 'กระแส': 2, 'การเมือง': 2, 'เศรษฐกิจ': 2, 'ต่างประเทศ': 4, 'อาชญากรรม': 2, 'ยานยนต์': 2, 'เทคโนโลยี': 2, 'ราคา': 4, 'ทองคำ': 2, 'ราย': 2, 'งานพิเศษ': 2, 'วิดีโอ': 4, 'หนังสือพิมพ์': 2, 'ทีวี': 2, 'ดู': 2, 'ย้อนหลัง': 2, 'ผัง': 2, 'รายการ': 3, 'live': 3, 'ไลฟ์สไตล์': 2, 'กีฬา': 5, 'ฟุตบอล': 6, 'sport': 2, 'insider': 2, 'ไฟต์': 2, 'สปอร์ต': 2, 'โลก': 4, 'แกลเลอรี่': 4, '2022': 2, 'บันเทิง': 5, 'ดวง': 2, 'หวย': 2, 'นิยาย': 2, 'โปรโมชั่น': 3, 'ซื้อ': 2, '-': 4, 'ขาย': 2, 'ส่วนลด': 2, 'เช็ค': 2, 'thairathpluslivelive': 1, 'เข้าสู่ระบบ': 2, 'สมัคร': 2, 'สมาชิก': 2, 'ค้นหา': 2, 'hamburgerhamburger': 1, 'thairath': 3, 'membership': 1, 'ชม': 1, 'สด': 1, 'back': 4, 'ล่าสุด': 1, 'วาไรตี้': 1, 'talk': 1, 'คอลัมน์': 1, 'podcast': 1, 'กิจกรรม': 1, 'plusbackthairath': 1, 'plusspeakmoneyeveryday': 1, 'lifenature': 1, 'mattersubculturefuturismsparkmirrorbackmirror': 1, '100': 1, 'ปี': 1, 'ชาต': 1, 'กาล': 1, 'กำ': 1, 'พล': 2, 'วัชร': 1, 'ร่วมงาน': 1, 'กับ': 3, 'เรา': 3, 'เกี่ยวกับ': 1, 'ติดต่อ': 2, 'โฆษณา': 1, 'facebookfacebooktwittertwitterinstagraminstagramyoutubeyoutube': 1, 'infographic': 1, 'มัลติมีเดีย': 1, 'บัว': 4, 'นลิน': 3, 'ทิพย์': 3, 'ฉีก': 2, 'ทุก': 4, 'บทบาท': 2, 'ที่': 6, 'เคย': 2, 'ได้รับ': 2, 'ละคร': 2, '“': 4, 'มณี': 3, 'พยาบาท': 3, '”': 6, 'โดย': 1, '16': 1, 'ภาพ': 1, '11': 1, 'มี': 1, '.ค.': 1, '2566': 1, '16:05': 1, 'นางเอก': 1, 'สาว': 2, 'หน้าหวาน': 1, 'ตาโต': 1, 'สกุล': 1, 'อ่อง': 1, 'อำไพ': 1, 'เสิร์ฟ': 1, 'ความ': 2, 'ปัง': 1, '!!': 1, 'ผลงาน': 1, 'เรื่อง': 2, 'แรก': 1, 'ถ่ายทำ': 1, 'หลัง': 1, 'ผัน': 1, 'ตัว': 1, 'มา': 1, 'เป็น': 1, 'นักแสดง': 2, 'อิสระ': 2, 'ทาง': 1, 'ช่อง': 1, 'วัน': 1, '31': 1, 'จับคู่': 1, 'พระเอก': 1, 'หน้า': 1, 'ใส': 1, 'นิว': 2, '–': 1, 'ฐิติ': 2, 'ภูมิ': 2, 'เต': 1, 'ชะ': 1, 'อภัย': 1, 'คุณ': 1, 'ถ่ายทอด': 1, 'บท': 1, 'สุด': 2, 'ท้าทาย': 1, 'ความรัก': 1,  ...
# {'link': 'http://www.thairath.co.th/multimedia/gallery/entertain/news/34218', 'title': 'บูม-พิ้งค์พลอย ชวนลุ้นระทึก ตามหาความลับที่ซ่อนอยู่ใน "เคหาสน์นางคอย"', 'body': ['ไทยรัฐ สำนักข่าวอันดับ 1 ของไทย | ไทยรัฐออนไลน์ไทยรัฐออนไลน์ข่าวพระราชสำนักทั่วไทยในกระแสการเมืองเศรษฐกิจต่างประเทศอาชญากรรมยานยนต์เทคโนโลยีราคาทองคำรายงานพิเศษวิดีโอหนังสือพิมพ์ไทยรัฐทีวีดูย้อนหลังผังรายการliveไลฟ์สไตล์กีฬาฟุตบอลต่างประเทศฟุตบอลไทยsport insiderไฟต์สปอร์ตกีฬาโลกวิดีโอแกลเลอรี่ฟุตบอลโลก 2022บันเทิงดวงหวยนิยายโปรโมชั่นซื้อ-ขายส่วนลดเช็คราคาthairathplusliveliveเข้าสู่ระบบสมัครสมาชิกค้นหาhamburgerhamburgerค้นหาthairath membershipเข้าสู่ระบบสมัครสมาชิกlive ชมรายการสดข่าวbackข่าวข่าวล่าสุดพระราชสำนักทั่วไทยในกระแสการเมืองเศรษฐกิจต่างประเทศอาชญากรรมยานยนต์เทคโนโลยีราคาทองคำรายงานพิเศษกีฬาbackฟุตบอลต่างประเทศฟุตบอลไทยsport insiderไฟต์สปอร์ตกีฬาโลกวิดีโอแกลเลอรี่ฟุตบอลโลก 2022ไทยรัฐทีวีbackดูย้อนหลังวาไรตี้บันเทิงกีฬาผังรายการliveโปรโมชั่นbackโปรโมชั่นซื้อ-ขายส่วนลดเช็คราคาthairath talkหนังสือพิมพ์คอลัมน์บันเทิงดวงหวยนิยายวิดีโอpodcastไลฟ์สไตล์กิจกรรมthairath plusbackthairath plusspeakmoneyeveryday lifenature mattersubculturefuturismsparkmirrorbackmirror100 ปี ชาตกาล  กำพล วัชรพลร่วมงานกับเราเกี่ยวกับเราติดต่อเราติดต่อโฆษณาfacebookfacebooktwittertwitterinstagraminstagramyoutubeyoutubeบันเทิงแกลเลอรี่infographicไทยรัฐออนไลน์มัลติมีเดียแกลเลอรี่บันเทิงบูม-พิ้งค์พลอย ชวนลุ้นระทึก ตามหาความลับที่ซ่อนอยู่ใน "เคหาสน์นางคอย"โดย ไทยรัฐออนไลน์18 ภาพ10 ธ.ค. 2565 15:37\xa0"ณ เคหาสน์นางคอย มีความลับที่ถูกซ่อนเร้น ความจริงที่ถูกกักขัง กับการรอคอยใครบางคนอย่างมีความหวังทุกลมหายใจ และเป็นความลับที่อาจจะเปลี่ยนชีวิตใครบางคนไปตลอดกาล" แฟนๆ เตรียมพบกับละครดราม่าลึกลับ “เคหาสน์นางคอย” ทางช่อง 7hd บูม-กิตตน์ก้อง โคจรคู่ พิ้งค์พลอย-ปภาวดี เป็นครั้งแรก ร่วมด้วย โอ๊ต-รัฐธีร์, แบมแบม-ณศมน, หมู-ภูษณะ, นิต้า-นิคิต้า ที่จะมาปะทะฝีมือกับนักแสดงรุ่นพี่มากความสามารถอย่าง อ้อน-เกวลิน คอตแลนด์ ที่หวนคืนจอ ช่อง 7hd อีกครั้ง และยังมีนักแสดงมากฝีมืออีกคับคั่งแท็กที่เกี่ยวข้องเคหาสน์นางคอยเคหาสน์นางคอย ละครละคร เคหาสน์นางคอยเคหาสน์นางคอย เรื่องย่อเคหาสน์นางคอย เนื้อเรื่องเคหาสน์นางคอย ล่าสุดเคหาสน์นางคอย ตอนแรกเคหาสน์นางคอย ep 1เคหาสน์นางคอย นักแสดงบูม กิตตน์ก้องพิ้งค์พลอย ปภาวดีละครช่อง7ละครใหม่ละครวันนี้นิยายข่าววันนี้'], 'location': 'Thailand', 'word': {'ไทยรัฐ': 7, 'สำนักข่าว': 1, 'อันดับ': 1, '1': 2, 'ของ': 1, 'ไทย': 5, '|': 1, 'ออนไลน์': 4, 'ข่าว': 5, 'พระ': 2, 'ราชสำนัก': 2, 'ทั่ว': 2, 'ใน': 3, 'กระแส': 2, 'การเมือง': 2, 'เศรษฐกิจ': 2, 'ต่างประเทศ': 4, 'อาชญากรรม': 2, 'ยานยนต์': 2, 'เทคโนโลยี': 2, 'ราคา': 4, 'ทองคำ': 2, 'ราย': 2, 'งานพิเศษ': 2, 'วิดีโอ': 4, 'หนังสือพิมพ์': 2, 'ทีวี': 2, 'ดู': 2, 'ย้อนหลัง': 2, 'ผัง': 2, 'รายการ': 3, 'live': 3, 'ไลฟ์สไตล์': 2, 'กีฬา': 5, 'ฟุตบอล': 6, 'sport': 2, 'insider': 2, 'ไฟต์': 2, 'สปอร์ต': 2, 'โลก': 4, 'แกลเลอรี่': 4, '2022': 2, 'บันเทิง': 5, 'ดวง': 2, 'หวย': 2, 'นิยาย': 3, 'โปรโมชั่น': 3, 'ซื้อ': 2, '-': 10, 'ขาย': 2, 'ส่วนลด': 2, 'เช็ค': 2, 'thairathpluslivelive': 1, 'เข้าสู่ระบบ': 2, 'สมัคร': 2, 'สมาชิก': 2, 'ค้นหา': 2, 'hamburgerhamburger': 1, 'thairath': 3, 'membership': 1, 'ชม': 1, 'สด': 1, 'back': 4, 'ล่าสุด': 2, 'วาไรตี้': 1, 'talk': 1, 'คอลัมน์': 1, 'podcast': 1, 'กิจกรรม': 1, 'plusbackthairath': 1, 'plusspeakmoneyeveryday': 1, 'lifenature': 1, 'mattersubculturefuturismsparkmirrorbackmirror': 1, '100': 1, 'ปี': 1, 'ชาต': 1, 'กาล': 1, 'กำ': 1, 'พล': 2, 'วัชร': 1, 'ร่วมงาน': 1, 'กับ': 4, 'เรา': 3, 'เกี่ยวกับ': 1, 'ติดต่อ': 2, 'โฆษณา': 1, 'facebookfacebooktwittertwitterinstagraminstagramyoutubeyoutube': 1, 'infographic': 1, 'มัลติมีเดีย': 1, 'บูม': 3, 'พิ้งค์': 3, 'พลอย': 3, 'ชวน': 1, 'ลุ้น': 1, 'ระทึก': 1, 'ตามหา': 1, 'ความลับ': 2, 'ที่ซ่อน': 1, 'อยู่': 1, 'เค': 12, 'หาสน์': 12, 'นาง': 12, 'คอย': 12, 'โดย': 1, '18': 1, 'ภาพ': 1, '10': 1, 'ธ.ค.': 1, '2565': 1, '15:37': 1, 'ณ': 1, 'มี': 1, 'ที่': 5, 'ถูก': 2, 'ซ่อนเร้น': 1, 'ความจริง': 1, 'กักขัง': 1, 'การรอคอย': 1, 'ใคร': 2, 'บางคน': 2, 'อย่าง': 2, 'มีความหวัง': 1, 'ทุก': 1, 'ลมหายใจ': 1, 'และ': 2, 'เป็นความลับ': 1, 'อาจจะ': 1, 'เปลี่ยน': 1, 'ชีวิต': 1, 'ไป': 1, 'ตลอดกาล': 1, 'แฟน': 1, ...
# {'link': 'http://www.thairath.co.th/business/investment/gold/topic', 'title': 'ข่าวราคาทองคำ | ไทยรัฐออนไลน์', 'body': ['ไทยรัฐ สำนักข่าวอันดับ 1 ของไทย | ไทยรัฐออนไลน์ไทยรัฐออนไลน์ข่าวพระราชสำนักทั่วไทยในกระแสการเมืองเศรษฐกิจต่างประเทศอาชญากรรมยานยนต์เทคโนโลยีราคาทองคำรายงานพิเศษวิดีโอหนังสือพิมพ์ไทยรัฐทีวีดูย้อนหลังผังรายการliveไลฟ์สไตล์กีฬาฟุตบอลต่างประเทศฟุตบอลไทยsport insiderไฟต์สปอร์ตกีฬาโลกวิดีโอแกลเลอรี่ฟุตบอลโลก 2022บันเทิงดวงหวยนิยายโปรโมชั่นซื้อ-ขายส่วนลดเช็คราคาthairathplusliveliveเข้าสู่ระบบสมัครสมาชิกค้นหาhamburgerhamburgerค้นหาthairath membershipเข้าสู่ระบบสมัครสมาชิกlive ชมรายการสดข่าวbackข่าวข่าวล่าสุดพระราชสำนักทั่วไทยในกระแสการเมืองเศรษฐกิจต่างประเทศอาชญากรรมยานยนต์เทคโนโลยีราคาทองคำรายงานพิเศษกีฬาbackฟุตบอลต่างประเทศฟุตบอลไทยsport insiderไฟต์สปอร์ตกีฬาโลกวิดีโอแกลเลอรี่ฟุตบอลโลก 2022ไทยรัฐทีวีbackดูย้อนหลังวาไรตี้บันเทิงกีฬาผังรายการliveโปรโมชั่นbackโปรโมชั่นซื้อ-ขายส่วนลดเช็คราคาthairath talkหนังสือพิมพ์คอลัมน์บันเทิงดวงหวยนิยายวิดีโอpodcastไลฟ์สไตล์กิจกรรมthairath plusbackthairath plusspeakmoneyeveryday lifenature mattersubculturefuturismsparkmirrorbackmirror100 ปี ชาตกาล  กำพล วัชรพลร่วมงานกับเราเกี่ยวกับเราติดต่อเราติดต่อโฆษณาfacebookfacebooktwittertwitterinstagraminstagramyoutubeyoutubeข่าวราคาทองคำ'], 'location': 'Thailand', 'word': {'ไทยรัฐ': 5, 'สำนักข่าว': 1, 'อันดับ': 1, '1': 1, 'ของ': 1, 'ไทย': 5, '|': 1, 'ออนไลน์': 2, 'ข่าว': 5, 'พระ': 2, 'ราชสำนัก': 2, 'ทั่ว': 2, 'ใน': 2, 'กระแส': 2, 'การเมือง': 2, 'เศรษฐกิจ': 2, 'ต่างประเทศ': 4, 'อาชญากรรม': 2, 'ยานยนต์': 2, 'เทคโนโลยี': 2, 'ราคา': 5, 'ทองคำ': 3, 'ราย': 2, 'งานพิเศษ': 2, 'วิดีโอ': 4, 'หนังสือพิมพ์': 2, 'ทีวี': 2, 'ดู': 2, 'ย้อนหลัง': 2, 'ผัง': 2, 'รายการ': 3, 'live': 3, 'ไลฟ์สไตล์': 2, 'กีฬา': 5, 'ฟุตบอล': 6, 'sport': 2, 'insider': 2, 'ไฟต์': 2, 'สปอร์ต': 2, 'โลก': 4, 'แกลเลอรี่': 2, '2022': 2, 'บันเทิง': 3, 'ดวง': 2, 'หวย': 2, 'นิยาย': 2, 'โปรโมชั่น': 3, 'ซื้อ': 2, '-': 2, 'ขาย': 2, 'ส่วนลด': 2, 'เช็ค': 2, 'thairathpluslivelive': 1, 'เข้าสู่ระบบ': 2, 'สมัคร': 2, 'สมาชิก': 2, 'ค้นหา': 2, 'hamburgerhamburger': 1, 'thairath': 3, 'membership': 1, 'ชม': 1, 'สด': 1, 'back': 4, 'ล่าสุด': 1, 'วาไรตี้': 1, 'talk': 1, 'คอลัมน์': 1, 'podcast': 1, 'กิจกรรม': 1, 'plusbackthairath': 1, 'plusspeakmoneyeveryday': 1, 'lifenature': 1, 'mattersubculturefuturismsparkmirrorbackmirror': 1, '100': 1, 'ปี': 1, 'ชาต': 1, 'กาล': 1, 'กำ': 1, 'พล': 2, 'วัชร': 1, 'ร่วมงาน': 1, 'กับ': 1, 'เรา': 3, 'เกี่ยวกับ': 1, 'ติดต่อ': 2, 'โฆษณา': 1, 'facebookfacebooktwittertwitterinstagraminstagramyoutubeyoutube': 1}, 'ref': 0}
